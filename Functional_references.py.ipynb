# %%
from prompt_toolkit.key_binding.bindings.named_commands import uppercase_word


def l_length(lst):
    return count(lst)
count=len
numbers=[1,2,3,4,5,6]
print(l_length(numbers))
# Out:
# 6

# %%
def run_twice(func,value):
    return func(func(value))
def double(x):
    return x*2
print(run_twice(double,5))
# Out:
# 20

# %%
# Store string methods in a dictionary
select = {
    'upper': str.upper,
    'lower': str.lower,
    'title': str.title
}

word = input("Enter a word: ")
choice = input("Choose upper, lower, or title: ")

print(select[choice](word))
# Out:
# AMAR
